# %%
#from google.colab import drive
#drive.mount('/content/drive/',True)
#!cp "/content/drive/Shared drives/Proyecto Final/4. Diseño Basico/Algortimo Genetico Cinematico/ga.py" "ga.py"
#!cp "/content/drive/Shared drives/Proyecto Final/4. Diseño Basico/Algortimo Genetico Cinematico/GlobalIndexKinematical.py" "GlobalIndexKinematical.py"

# %%
import numpy as np
import matplotlib.pyplot as plt
import ga
import GlobalIndexKinematical as km

# %%
# Inputs or constants
span = [[500,50,50,-50],[700,150,250,50]]

# Number of variables for optimization
num_var = 4
num_kromo = 25 # Number of Chromosomes
k = 100 # Number of Generations
pop_size = (num_kromo, 1)

# Random Population
new_pop1 = np.random.uniform(span[0][0], span[1][0], size=pop_size)
new_pop2 = np.random.uniform(span[0][1], span[1][1], size=pop_size)
new_pop3 = np.random.uniform(span[0][2], span[1][2], size=pop_size)
new_pop4 = np.random.uniform(span[0][3], span[1][3], size=pop_size)

new_population = np.concatenate((new_pop1,new_pop2, new_pop3, new_pop4),axis=1)
print('Random Population:\n',new_population,'\n')

# Point Cloud
P = km.WorkspaceDesired(500.0,650.0,50.0)

# Number of Parents
num_parents = int(num_kromo/2)

Global_fitness = []
Avg_fitness=[]
Elite = []
# Out:
# Random Population:
#  [[ 6.92767189e+02  1.25598934e+02  6.86698035e+01 -3.97599361e+00]
#  [ 6.61699780e+02  1.31247010e+02  5.19448931e+01 -1.08372879e+01]
#  [ 6.45899126e+02  1.40420739e+02  8.72193984e+01  1.74541933e+01]
#  [ 5.08185869e+02  8.34649762e+01  2.27108711e+02  2.64237721e+01]
#  [ 5.98485322e+02  1.37573348e+02  2.38480591e+02 -4.42772946e+01]
#  [ 6.11746130e+02  9.04814880e+01  1.98885528e+02 -3.32970202e+00]
#  [ 6.77270510e+02  9.45392171e+01  2.20080874e+02 -6.81344092e-01]
#  [ 6.73177581e+02  8.31149856e+01  2.16679455e+02 -4.34454584e+01]
#  [ 6.38062526e+02  7.99022358e+01  1.58112699e+02  3.32518559e+01]
#  [ 5.30262639e+02  6.08773455e+01  2.44846099e+02  4.71769862e+00]
#  [ 6.16648876e+02  1.47617218e+02  1.01504824e+02 -2.22421104e+01]
#  [ 6.60613624e+02  1.05087542e+02  1.63825099e+02 -1.89462208e+01]
#  [ 6.37311976e+02  5.86457647e+01  1.73102720e+02 -4.73284536e+01]
#  [ 6.82271920e+02  6.40093835e+01  1.03301237e+02  1.96015777e+01]
#  [ 6.38770540e+02  1.37928283e+02  1.18377233e+02 -3.22768470e+01]
#  [ 5.10323577e+02  6.35758927e+01  2.28212119e+02 -3.03427517e+01]
#  [ 6.99594607e+02  6.80215330e+01  6.98369397e+01 -4.69071078e+00]
#  [ 6.40792007e+02  1.05794555e+02  1.67061123e+02  6.94095879e+00]
#  [ 6.24089972e+02  9.85904424e+01  6.85477105e+01 -2.46683483e+00]
#  [ 6.05953081e+02  1.05818773e+02  1.10732588e+02  3.00445403e+01]
#  [ 5.18713018e+02  1.48304605e+02  2.27888187e+02 -4.73997781e+01]
#  [ 6.96899219e+02  1.33225876e+02  2.31577663e+02  3.69459969e+01]
#  [ 5.29362761e+02  7.76391866e+01  5.97513235e+01 -1.27021103e+00]
#  [ 5.87706631e+02  6.94406374e+01  1.54570029e+02  3.53311009e+01]
#  [ 6.56590360e+02  5.03822189e+01  1.83972610e+02 -1.81821333e+01]]

# %%
for i in range(k):
    # Evaluate Fitness
    print('\n',f'Evaluate Fitness of Generation {i}:')
    fitness = ga.fitnessK(new_population,P,False)
    Global_fitness.append(max(fitness))
    Avg_fitness.append(np.average(fitness))
    print(f'Maximun Fitness: {Global_fitness[-1]} and Mean Fitness: {Avg_fitness[-1]}')
    Elite.append(new_population[fitness.index(Global_fitness[-1])])

    # Select Best Fitness
    parents = ga.select_parents(new_population,fitness,num_parents)
    #print('Parents Selected:\n',parents, '\n')

    # Crossover
    offspring_cross = ga.crossover(parents,num_kromo)
    #print('crossover:\n',offspring_cross, '\n')

    # Mutation
    mut_prob = 0.6
    offspring_mut = ga.mutation(offspring_cross,span, mut_prob)
    #print('Mutation:\n',offspring_mut, '\n')

    # Pop
    new_population = np.concatenate((parents, offspring_mut))
    #print('Generation ', i, ':\n', new_population)
    
# Evaluate Fitness
print('\n',f'Evaluate Fitness of Generation {k}:')
fitness = ga.fitnessK(new_population,P)
Global_fitness.append(max(fitness))
Avg_fitness.append(np.average(fitness))
print(f'Maximun Fitness: {Global_fitness[-1]} and Mean Fitness: {Avg_fitness[-1]}')
Elite.append(new_population[fitness.index(Global_fitness[-1])])
# Out:
#  Evaluate Fitness of Generation 0:
# Maximun Fitness: 1.4837485162959745 and Mean Fitness: 1.3559988228445803
#
#  Evaluate Fitness of Generation 1:
# Maximun Fitness: 1.5365919197764721 and Mean Fitness: 1.392435074156334
#
#  Evaluate Fitness of Generation 2:
# Maximun Fitness: 1.5365919197764721 and Mean Fitness: 1.4537818980600963
#
#  Evaluate Fitness of Generation 3:
# Maximun Fitness: 1.5386399753441866 and Mean Fitness: 1.478479720846861
#
#  Evaluate Fitness of Generation 4:
# Maximun Fitness: 1.5386399753441866 and Mean Fitness: 1.5090215663119815
#
#  Evaluate Fitness of Generation 5:
# Maximun Fitness: 1.5386399753441866 and Mean Fitness: 1.4783307904954195
#
#  Evaluate Fitness of Generation 6:
# Maximun Fitness: 1.542659300528366 and Mean Fitness: 1.5036208175653905
#
#  Evaluate Fitness of Generation 7:
# Maximun Fitness: 1.542659300528366 and Mean Fitness: 1.5049938186670175
#
#  Evaluate Fitness of Generation 8:
# Maximun Fitness: 1.542659300528366 and Mean Fitness: 1.5049327250002946
#
#  Evaluate Fitness of Generation 9:
# Maximun Fitness: 1.542663563130835 and Mean Fitness: 1.5122285081917262
#
#  Evaluate Fitness of Generation 10:
# Maximun Fitness: 1.542663563130835 and Mean Fitness: 1.5111865007278829
#
#  Evaluate Fitness of Generation 11:
# Maximun Fitness: 1.5429912966141803 and Mean Fitness: 1.5077290007255395
#
#  Evaluate Fitness of Generation 12:
# Maximun Fitness: 1.5429912966141803 and Mean Fitness: 1.5167891288966868
#
#  Evaluate Fitness of Generation 13:
# Maximun Fitness: 1.544937211926666 and Mean Fitness: 1.499448679621598
#
#  Evaluate Fitness of Generation 14:
# Maximun Fitness: 1.544937211926666 and Mean Fitness: 1.4942196410106288
#
#  Evaluate Fitness of Generation 15:
# Maximun Fitness: 1.544937211926666 and Mean Fitness: 1.514828875322669
#
#  Evaluate Fitness of Generation 16:
# Maximun Fitness: 1.5457214018398262 and Mean Fitness: 1.5182459443815055
#
#  Evaluate Fitness of Generation 17:
# Maximun Fitness: 1.5457214018398262 and Mean Fitness: 1.5071246151175857
#
#  Evaluate Fitness of Generation 18:
# Maximun Fitness: 1.5457214018398262 and Mean Fitness: 1.5165333572536097
#
#  Evaluate Fitness of Generation 19:
# Maximun Fitness: 1.5457214018398262 and Mean Fitness: 1.5162510091012797
#
#  Evaluate Fitness of Generation 20:
# Maximun Fitness: 1.5457214018398262 and Mean Fitness: 1.493037270179711
#
#  Evaluate Fitness of Generation 21:
# Maximun Fitness: 1.5457214018398262 and Mean Fitness: 1.5095904636414255
#
#  Evaluate Fitness of Generation 22:
# Maximun Fitness: 1.5458166415722754 and Mean Fitness: 1.5046768765706653
#
#  Evaluate Fitness of Generation 23:
# Maximun Fitness: 1.5458166415722754 and Mean Fitness: 1.505406047241831
#
#  Evaluate Fitness of Generation 24:
# Maximun Fitness: 1.5458166415722754 and Mean Fitness: 1.5208575026576403
#
#  Evaluate Fitness of Generation 25:
# Maximun Fitness: 1.5458166415722754 and Mean Fitness: 1.5113852493857283
#
#  Evaluate Fitness of Generation 26:
# Maximun Fitness: 1.5458166415722754 and Mean Fitness: 1.5071683135950715
#
#  Evaluate Fitness of Generation 27:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5157613060890507
#
#  Evaluate Fitness of Generation 28:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5274080575478446
#
#  Evaluate Fitness of Generation 29:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5160028178680995
#
#  Evaluate Fitness of Generation 30:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.510984372500925
#
#  Evaluate Fitness of Generation 31:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.4978177794816592
#
#  Evaluate Fitness of Generation 32:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.506369256129512
#
#  Evaluate Fitness of Generation 33:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5121817375340987
#
#  Evaluate Fitness of Generation 34:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5173962236509564
#
#  Evaluate Fitness of Generation 35:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5128478196326989
#
#  Evaluate Fitness of Generation 36:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5018216460079
#
#  Evaluate Fitness of Generation 37:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5076344443863294
#
#  Evaluate Fitness of Generation 38:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5099143572442877
#
#  Evaluate Fitness of Generation 39:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.526300035076115
#
#  Evaluate Fitness of Generation 40:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5235224385544712
#
#  Evaluate Fitness of Generation 41:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.4982609792176333
#
#  Evaluate Fitness of Generation 42:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5145483992222344
#
#  Evaluate Fitness of Generation 43:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.52765632555783
#
#  Evaluate Fitness of Generation 44:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.513602371679424
#
#  Evaluate Fitness of Generation 45:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5007575773334145
#
#  Evaluate Fitness of Generation 46:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5130462584474935
#
#  Evaluate Fitness of Generation 47:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.4878875967962013
#
#  Evaluate Fitness of Generation 48:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.500902181372829
#
#  Evaluate Fitness of Generation 49:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5056693497481894
#
#  Evaluate Fitness of Generation 50:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5158270973688088
#
#  Evaluate Fitness of Generation 51:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.4829892468009467
#
#  Evaluate Fitness of Generation 52:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5247429539485184
#
#  Evaluate Fitness of Generation 53:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5021070474519715
#
#  Evaluate Fitness of Generation 54:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.4880321389227875
#
#  Evaluate Fitness of Generation 55:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.4939622223853555
#
#  Evaluate Fitness of Generation 56:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5343977134548712
#
#  Evaluate Fitness of Generation 57:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.516971524856941
#
#  Evaluate Fitness of Generation 58:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5107897653856295
#
#  Evaluate Fitness of Generation 59:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.4992737763474338
#
#  Evaluate Fitness of Generation 60:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5124767210836687
#
#  Evaluate Fitness of Generation 61:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.4953805973153722
#
#  Evaluate Fitness of Generation 62:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5069450734972223
#
#  Evaluate Fitness of Generation 63:
# Maximun Fitness: 1.54593504435893 and Mean Fitness: 1.5099196961867245
#
#  Evaluate Fitness of Generation 64:
# Maximun Fitness: 1.5459571961713041 and Mean Fitness: 1.5126225446030965
#
#  Evaluate Fitness of Generation 65:
# Maximun Fitness: 1.5459571961713041 and Mean Fitness: 1.5211019510638921
#
#  Evaluate Fitness of Generation 66:
# Maximun Fitness: 1.5459571961713041 and Mean Fitness: 1.5120098587680397
#
#  Evaluate Fitness of Generation 67:
# Maximun Fitness: 1.5459571961713041 and Mean Fitness: 1.5168779328020485
#
#  Evaluate Fitness of Generation 68:
# Maximun Fitness: 1.5459571961713041 and Mean Fitness: 1.5020767151575172
#
#  Evaluate Fitness of Generation 69:
# Maximun Fitness: 1.5459571961713041 and Mean Fitness: 1.5054760230010826
#
#  Evaluate Fitness of Generation 70:
# Maximun Fitness: 1.5459571961713041 and Mean Fitness: 1.5020303190774411
#
#  Evaluate Fitness of Generation 71:
# Maximun Fitness: 1.5459571961713041 and Mean Fitness: 1.5190436966538607
#
#  Evaluate Fitness of Generation 72:
# Maximun Fitness: 1.5459571961713041 and Mean Fitness: 1.5163353294869453
#
#  Evaluate Fitness of Generation 73:
# Maximun Fitness: 1.5460971049060868 and Mean Fitness: 1.5112997028298796
#
#  Evaluate Fitness of Generation 74:
# Maximun Fitness: 1.5460971049060868 and Mean Fitness: 1.5244616483612619
#
#  Evaluate Fitness of Generation 75:
# Maximun Fitness: 1.5460971049060868 and Mean Fitness: 1.5215468903316902
#
#  Evaluate Fitness of Generation 76:
# Maximun Fitness: 1.5460971049060868 and Mean Fitness: 1.5105980850839529
#
#  Evaluate Fitness of Generation 77:
# Maximun Fitness: 1.5460971049060868 and Mean Fitness: 1.5162251146807029
#
#  Evaluate Fitness of Generation 78:
# Maximun Fitness: 1.5460971049060868 and Mean Fitness: 1.5212496491047693
#
#  Evaluate Fitness of Generation 79:
# Maximun Fitness: 1.5460971049060868 and Mean Fitness: 1.492201886735375
#
#  Evaluate Fitness of Generation 80:
# Maximun Fitness: 1.5460971049060868 and Mean Fitness: 1.5113744710255912
#
#  Evaluate Fitness of Generation 81:
# Maximun Fitness: 1.5460971049060868 and Mean Fitness: 1.493583081449436
#
#  Evaluate Fitness of Generation 82:
# Maximun Fitness: 1.546201833046743 and Mean Fitness: 1.5126397783703396
#
#  Evaluate Fitness of Generation 83:
# Maximun Fitness: 1.546201833046743 and Mean Fitness: 1.5036598781335344
#
#  Evaluate Fitness of Generation 84:
# Maximun Fitness: 1.546201833046743 and Mean Fitness: 1.5173327184596146
#
#  Evaluate Fitness of Generation 85:
# Maximun Fitness: 1.546201833046743 and Mean Fitness: 1.511722910932545
#
#  Evaluate Fitness of Generation 86:
# Maximun Fitness: 1.546201833046743 and Mean Fitness: 1.5041451365438328
#
#  Evaluate Fitness of Generation 87:
# Maximun Fitness: 1.546201833046743 and Mean Fitness: 1.5057100703891755
#
#  Evaluate Fitness of Generation 88:
# Maximun Fitness: 1.546201833046743 and Mean Fitness: 1.5061424427642593
#
#  Evaluate Fitness of Generation 89:
# Maximun Fitness: 1.546201833046743 and Mean Fitness: 1.518787971167123
#
#  Evaluate Fitness of Generation 90:
# Maximun Fitness: 1.546201833046743 and Mean Fitness: 1.4846362693321513
#
#  Evaluate Fitness of Generation 91:
# Maximun Fitness: 1.546201833046743 and Mean Fitness: 1.4925177232708087
#
#  Evaluate Fitness of Generation 92:
# Maximun Fitness: 1.546201833046743 and Mean Fitness: 1.5122641087231765
#
#  Evaluate Fitness of Generation 93:
# Maximun Fitness: 1.546201833046743 and Mean Fitness: 1.510508574503906
#
#  Evaluate Fitness of Generation 94:
# Maximun Fitness: 1.546201833046743 and Mean Fitness: 1.5235843165341847
#
#  Evaluate Fitness of Generation 95:
# Maximun Fitness: 1.546201833046743 and Mean Fitness: 1.5253440937345546
#
#  Evaluate Fitness of Generation 96:
# Maximun Fitness: 1.546201833046743 and Mean Fitness: 1.5089729025576708
#
#  Evaluate Fitness of Generation 97:
# Maximun Fitness: 1.546201833046743 and Mean Fitness: 1.5041345143926756
#
#  Evaluate Fitness of Generation 98:
# Maximun Fitness: 1.546201833046743 and Mean Fitness: 1.5111498687040186
#
#  Evaluate Fitness of Generation 99:
# Maximun Fitness: 1.546201833046743 and Mean Fitness: 1.4957264293017183
#
#  Evaluate Fitness of Generation 100:
# Chromosome  1 - fitness  1.546201833046743
# Chromosome  2 - fitness  1.546201833046743
# Chromosome  3 - fitness  1.546201833046743
# Chromosome  4 - fitness  1.546201833046743
# Chromosome  5 - fitness  1.546201833046743
# Chromosome  6 - fitness  1.546201833046743
# Chromosome  7 - fitness  1.546201833046743
# Chromosome  8 - fitness  1.546201833046743
# Chromosome  9 - fitness  1.546201833046743
# Chromosome  10 - fitness  1.546201833046743
# Chromosome  11 - fitness  1.546201833046743
# Chromosome  12 - fitness  1.546201833046743
# Chromosome  13 - fitness  1.546201833046743
# Chromosome  14 - fitness  1.4881782814886342
# Chromosome  15 - fitness  1.546201833046743
# Chromosome  16 - fitness  1.3805428964406403
# Chromosome  17 - fitness  1.5432994057143414
# Chromosome  18 - fitness  1.3819393378937528
# Chromosome  19 - fitness  1.2923630535816373
# Chromosome  20 - fitness  1.4032074983380904
# Chromosome  21 - fitness  1.364373779550235
# Chromosome  22 - fitness  1.3914372995572375
# Chromosome  23 - fitness  1.4759958807132205
# Chromosome  24 - fitness  1.5110879494652416
# Chromosome  25 - fitness  1.5460670846094773
# Chromosome  26 - fitness  1.536683666910681
# Chromosome  27 - fitness  1.546201833046743
# Chromosome  28 - fitness  1.3830054627713801
# Chromosome  29 - fitness  1.546201833046743
# Chromosome  30 - fitness  1.546201833046743
# Chromosome  31 - fitness  1.546201833046743
# Chromosome  32 - fitness  1.5057247581843711
# Chromosome  33 - fitness  1.4636601751002107
# Chromosome  34 - fitness  1.546201833046743
# Chromosome  35 - fitness  1.5321053939579248
# Chromosome  36 - fitness  1.546201833046743
# Chromosome  37 - fitness  1.5376563817521665
# Maximun Fitness: 1.546201833046743 and Mean Fitness: 1.5043612153233543

# %%
#print(Global_fitness)
print(f'Best Solution: {new_population[fitness.index(max(fitness))]}')

plt.plot(Global_fitness,'b-')
plt.plot(Avg_fitness,'r-')

plt.xlabel('# Generaciones')
plt.show()
# Out:
# Best Solution: [6.75094566e+02 5.00818563e+01 2.49309904e+02 4.83903096e-03]

# %%
np.savetxt('Records_Fitness.csv',(Global_fitness,Avg_fitness),fmt='%4.4f',delimiter=',',header='Maximun, Mean')
np.savetxt('Records_Elite.csv',Elite,fmt='%4.4f',delimiter=',',header='R_b, L_A, L_D, e',comments='Best of each Generation')
np.savetxt('Last_Generation.csv',new_population,fmt='%4.4f',delimiter=',',header='R_b, L_A, L_D, e')
np.savetxt('Last_Fitness.csv',np.matrix(fitness).T,fmt='%4.4f',delimiter=',',header='Fitness')

#!cp "Records_Fitness.csv" "/content/drive/Shared drives/Proyecto Final/4. Diseño Basico/Algortimo Genetico Cinematico/Records_Fitness.csv"
#!cp "Records_Elite.csv" "/content/drive/Shared drives/Proyecto Final/4. Diseño Basico/Algortimo Genetico Cinematico/Records_Elite.csv"
#!cp "Last_Generation.csv" "/content/drive/Shared drives/Proyecto Final/4. Diseño Basico/Algortimo Genetico Cinematico/Last_Generation.csv"
#!cp "Last_Fitness.csv" "/content/drive/Shared drives/Proyecto Final/4. Diseño Basico/Algortimo Genetico Cinematico/Last_Fitness.csv"
